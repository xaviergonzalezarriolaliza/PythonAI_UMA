# %% [markdown]
# ## Constructor, destructor and member variables

# %% [markdown]
# ### 1. Class:

# %% [markdown]
# #### 1.1. Constructor method:

# %%
# Define a class which represents a dog. It stores its name and age. 
class :                   # ADD CODE
    def ():               # ADD CODE. Constructor. Receives the self object and two parameters (name, age)
        self.name =       # ADD CODE. Assign the input parameter "name" 
        self.age  = age            # ADD CODE. Assign the input parameter "age" 
        print('A Dog object is created!')

# %%
a_dog =                   # ADD CODE. Create an object of the Dog class
# Out:
# A Dog object is created!

# %% [markdown]
# #### 1.2. Destructor method:

# %%
# Rewrite the previous class Dog with a destructor method.

class Dog:
    # ADD CODE of the constructor
    def :                 # ADD CODE. Define de destructor method (__del__). Receives the self object
        print('A Dog object is deleted!')

# %%
a_dog =                  # ADD CODE. Create an object of the Dog class
# Out:
# A Dog object is created!

# %%
                         # ADD CODE. Delete the a_dog object
# Out:
# A Dog object is deleted!

# %% [markdown]
# #### 1.3. Memeber variable:

# %%
dog1 =                   # ADD CODE. Create an object of the Dog with name "Fido" and age 2
dog2 =                   # ADD CODE. Create an object of the Dog with name "Dido" and age 3

# %%
print(f"Name: {doge1.name}")                  # ADD CODE. Show the members variables of the dog1 object
# Out:
# Name: Fido
# Age: 2

# %%
print()                  # ADD CODE. Show the members variables of the dog2 object
# Out:
# Name: Dido
# Age: 3

# %% [markdown]
# #### 1.4. Class variable:

# %%
class Dog:
    counter =                     # ADD CODE. Define a class variable assigned to 0
    def __init__(self, name):
        self.name = name
        Dog.counter ...           # ADD CODE. Increment the counter after the creation of an object
    def __del__(self):
        Dog.counter ...           # ADD CODE. Decrement the counter after the delete of an object

# %%
# ADD CODE. Create 2 Dog objects.

# %%
# ADD CODE. Show the class variable (counter) of the Dog class
print()
# Out:
# 2

# %%
# ADD CODE. Delete one object and show the counter
# Out:
# 1

# %%
# ADD CODE. Delete the second object and show the counter
# Out:
# 0

# %% [markdown]
# #### 1.5. Member method:

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def ...                       # ADD CODE. Define a method "bark" that show a personalized message

# %%
a_dog = Dog('Baduk', 2)
# ADD CODE. Call the member method "bark"
# Out:
# Baduk is barking... woof... woof...
